# %% [markdown]
# # ============================================================================
# ## Anomaly Detection AI Agent using Gemini 2.0 Flash
# ## This agent guides users through anomaly detection model selection using local tools.
# ## No data is sent to Gemini - only metadata and decision-making.
# # ============================================================================

# %%
# !pwd
# Out:
# /Users/puneetrathore/Documents/Puneet/Jupyter_notebooks/log_agenticAI/Model_dev_Auto

# %%
import os
import json
import pandas as pd
import numpy as np
from typing import Dict, List, Tuple, Any
import google.generativeai as genai
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import euclidean
from pyod.models.iforest import IForest
from pyod.models.vae import VAE
from pyod.models.auto_encoder import AutoEncoder
from pyod.models.ocsvm import OCSVM
from pyod.models.abod import ABOD
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
sys.path.append("/Users/puneetrathore/Documents/Puneet/Jupyter_notebooks/log_agenticAI/Model_dev_Auto/")

# %%
# %run support_files/Anomaly_detection_agent.ipynb
# %run support_files/Anomaly_detection_tools.ipynb

# %%
print("Please enter your Google AI API key for Gemini 2.0 Flash")
print("Get it from: https://aistudio.google.com/app/apikey")
api_key = "AIzaSyAqfqM3NRcLCsKDtrOncxMbkb7oVYBHZaw" #input("API Key: ").strip()

if not api_key:
    print("❌ API key is required")
    exit(1)

try:
    agent = AnomalyDetectionAgent(api_key)
    agent.run_pipeline()
except Exception as e:
    print(f"❌ Fatal error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Please enter your Google AI API key for Gemini 2.0 Flash
# Get it from: https://aistudio.google.com/app/apikey
# ...
# 🤖 ANOMALY DETECTION AI AGENT ACTIVATED
# Powered by Gemini 2.0 Flash
# ...
#
# 📊 STEP 1: Loading Training Dataset
# --------------------------------------------------------------------------------
# Enter training dataset path (CSV):  support_files/train_anomaly_dataset.csv
# ✅ Training data loaded successfully!
#    Rows: 5000
#    Columns: 10
#    Numeric features: 10
#
# 📊 STEP 2: Loading Test Dataset
# --------------------------------------------------------------------------------
# Enter test dataset path (CSV):  support_files/test_anomaly_dataset.csv
# ✅ Test data loaded successfully!
#    Rows: 1000
#
# 🎯 STEP 3: Feature Selection
# --------------------------------------------------------------------------------
# Available numeric columns: ['feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9', 'feature_10']
# ...

# %%
/Users/puneetrathore/Documents/Puneet/Jupyter_notebooks/input/train_anomaly_dataset.csv
# AIzaSyAqfqM3NRcLCsKDtrOncxMbkb7oVYBHZaw

# %%
# AnomalyDetectionTools.load_dataset("support_files/train_anomaly_dataset.csv")
AnomalyDetectionAgent.validate_file_path(None,"no
/train_anomaly_dataset.csv")
# Out:
# (True, 'File path is valid')
